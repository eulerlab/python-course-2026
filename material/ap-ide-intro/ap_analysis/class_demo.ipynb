# %%
import numpy as np

# %% [markdown]
# ### There is a terminal with the editor
#
#
# Create a virtual environment with the packages listed in requirements.txt:
#    ```
#    uv venv
#    uv pip install -r requirements.txt
#    ```

# %% [markdown]
# ### Autocomplete - vs code understands the programming language

# %%
some_list_with_super_long_and_unnecessary_name = [1,2,3,4,5,6,7]

# turn into array


# take the mean

# %% [markdown]
# ### Underline errors

# %%
some_array = np.array([1,2,

# %% [markdown]
# ### Hover documentation

# %%
# What does this do? 
np.argmax(some_array)

# %% [markdown]
# ### Highlighting equal words

# %%
sampling_rate = 100
duration = 5
n_samples = sampling_rate * duration
print(sampling_rate)

# %% [markdown]
# ### Click into things

# %%
def add_to_list(x):
    return some_list_with_super_long_and_unnecessary_name + x





###### a lot of code  



# bla bla 





## function used

add_to_list([3,55,67])

# %% [markdown]
# ### rename symbol

# %%
sampling_rate = 100
duration = 5
n_samples = sampling_rate * duration
print(sampling_rate)

# %% [markdown]
# ### Debug

# %%
# why is the number of samples so weird?
sampling_rate = 100
duration = 5
sampling_rate = str(sampling_rate)
n_samples = sampling_rate * duration
print(n_samples)
